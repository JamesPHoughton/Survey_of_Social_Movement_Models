# %%
# %pylab inline
import pysd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
model = pysd.read_vensim('Tsebelis_Sprague_1989_Simplified.mdl')

# %%
model.run().plot()
plt.xlabel('Time')
plt.ylabel('Normalized to Starting Condition')
#plt.figtext(.07, .8, 'Normalized to Starting Condition', ha='center', rotation=90)

# %%
model.run({'Coercive Influence on Revolution g':.01}).plot()
plt.xlabel('Time')
plt.ylabel('Normalized to Starting Condition')
