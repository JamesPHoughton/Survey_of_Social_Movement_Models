# %%
# %pylab inline
import numpy as np
import networkx as nx
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
g = nx.grid_2d_graph(8,8)
pos = dict( (n, n) for n in g.nodes() )
nx.draw_networkx(g, pos=pos)
plt.axis('off');
g.node[(0,1)]
# Out:
# {}

# %%
occupants = dict(zip(g.nodes(), np.random.choice([' ', 'A', 'B'], size=g.number_of_nodes())))
nx.set_node_attributes(g, 'occupant', occupants)

key = {' ':'w', 'A':'r', 'B':'b'}
colors = [key[g.node[n]['occupant']] for n in g.nodes() ]

g.node[(0,1)]
# Out:
# {'occupant': ' '}

# %%
nx.draw_networkx(g, pos=pos, node_color=colors)
plt.axis('off');

# %%
g.neighbors((0,1))
# Out:
# [(0, 0), (1, 1), (0, 2)]

# %%
def evaluate_neighborhood(g, n):
    neighbors = g.neighbors(n)
    occupants = [g.node[neighbor]['occupant'] for neighbor in neighbors]
    return occupants

evaluate_neighborhood(g, (0,1))
# Out:
# ['B', ' ', ' ']
